# %% [markdown]
# # CUSTOMER CHURN PREDICTION USING ANN

# %% [markdown]
# ## Importing Libraries

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the Dataframe

# %%
df = pd.read_csv("C:\\Amey C\\ML LEARNING CSV's\\WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3141  5649-ANRML    Male              1      No         No       2
# 6419  3865-ZYKAD    Male              1     Yes         No      69
# 4789  0511-JTEOY  Female              0      No         No       1
# 6529  7235-NXZCP    Male              1      No         No       2
# 3446  2000-MPKCA  Female              0      No         No      58
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 3141          Yes            No     Fiber optic             No  ...
# 6419          Yes           Yes     Fiber optic            Yes  ...
# 4789          Yes            No     Fiber optic             No  ...
# 6529          Yes           Yes     Fiber optic             No  ...
# 3446          Yes           Yes     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# ## Deleting useless columns

# %%
df.drop('customerID', axis = 'columns', inplace = True)

# %%
df.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 3388  Female              0     Yes         No      65          Yes
# 6683    Male              0      No         No      43           No
# 5143  Female              0     Yes        Yes      49          Yes
# 4282  Female              0     Yes        Yes      52          Yes
# 554     Male              0      No         No      32          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 3388                No             DSL            Yes           No
# 6683  No phone service             DSL             No           No
# 5143                No             DSL            Yes          Yes
# 4282               Yes     Fiber optic             No           No
# 554                Yes     Fiber optic             No          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
pd.to_numeric(df['TotalCharges'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\conda\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12400\4092668822.py in <module>
# ----> 1 pd.to_numeric(df['TotalCharges'])
#
# D:\conda\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     182         coerce_numeric = errors not in ("ignore", "raise")
#     183         try:
# --> 184             values, _ = lib.maybe_convert_numeric(
#     185                 values, set(), coerce_numeric=coerce_numeric
#     186             )
#
# D:\conda\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %% [markdown]
# ### ^ We can see that there are some strings that have blank spaces for total charges. Hence we cannot use to_numeric to change the data type

# %%
df[pd.to_numeric(df['TotalCharges'], errors = 'coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
df1 = df[df['TotalCharges'] != ' ']
df1.shape
# Out:
# (7032, 20)

# %%
pd.to_numeric(df1['TotalCharges'])
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7032, dtype: float64

# %%
df1['TotalCharges'] = pd.to_numeric(df1['TotalCharges'])
# Out:
# C:\Users\ameym\AppData\Local\Temp\ipykernel_12400\1462773625.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['TotalCharges'] = pd.to_numeric(df1['TotalCharges'])

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %% [markdown]
# ## Doing data exploration

# %%
df1[df1['Churn'] == 'No']
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 7037  Female              0      No         No      72          Yes
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 0     No phone service             DSL                   No
# ...

# %%
df1[df1['Churn'] == 'No'].tenure
# Out:
# 0        1
# 1       34
# 3       45
# 6       22
# 7       10
#         ..
# 7037    72
# 7038    24
# 7039    72
# 7040    11
# 7042    66
# Name: tenure, Length: 5163, dtype: int64

# %%
tenure_churn_no = df1[df1['Churn'] == 'No'].tenure
tenure_churn_yes = df1[df1['Churn'] == 'Yes'].tenure

#Plotting hsitograms to check for any patterns


plt.hist([tenure_churn_no, tenure_churn_yes], color = ["Blue", 'Green'], label = ["Churn_no", 'churn_yes'])
plt.legend()

# %%
mc_churn_no = df1[df1.Churn=='No'].MonthlyCharges      
mc_churn_yes = df1[df1.Churn=='Yes'].MonthlyCharges      


plt.title("Customer Churn Prediction Visualiztion for Monthly Charges")
plt.hist([mc_churn_yes, mc_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
df1.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 12      Male              0     Yes         No      58          Yes
# 1742  Female              0      No         No       2          Yes
# 84    Female              0     Yes         No      49          Yes
# 967     Male              0      No        Yes       3          Yes
# 6894    Male              1     Yes         No       3          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 12             Yes     Fiber optic                   No                   No
# 1742            No     Fiber optic                   No                  Yes
# 84              No              No  No internet service  No internet service
# 967             No              No  No internet service  No internet service
# 6894           Yes     Fiber optic                   No                  Yes
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
def print_unique_columns_values(df):
    for column in df:
        if df[column].dtype == 'object':
            print(f'{column} : {df[column].unique()} ')

# %%
print_unique_columns_values(df1)
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No phone service' 'No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes' 'No internet service']
# OnlineBackup : ['Yes' 'No' 'No internet service']
# DeviceProtection : ['No' 'Yes' 'No internet service']
# TechSupport : ['No' 'Yes' 'No internet service']
# StreamingTV : ['No' 'Yes' 'No internet service']
# StreamingMovies : ['No' 'Yes' 'No internet service']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']

# %%
df1.replace('No internet service', 'No', inplace = True)
df1.replace('No phone service', 'No', inplace = True)
# Out:
# C:\Users\ameym\AppData\Local\Temp\ipykernel_12400\494651664.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service', 'No', inplace = True)
# C:\Users\ameym\AppData\Local\Temp\ipykernel_12400\494651664.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service', 'No', inplace = True)

# %%
print_unique_columns_values(df1)
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes']
# OnlineBackup : ['Yes' 'No']
# DeviceProtection : ['No' 'Yes']
# TechSupport : ['No' 'Yes']
# StreamingTV : ['No' 'Yes']
# StreamingMovies : ['No' 'Yes']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']

# %% [markdown]
# ### Converting the yes/no values to 1/0:

# %%
yes_no_columns = ['Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'Churn']

for col in yes_no_columns:
    df1[col].replace({'Yes' : 1, 'No' : 0}, inplace = True)
# Out:
# C:\Users\ameym\AppData\Local\Temp\ipykernel_12400\2561534203.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({'Yes' : 1, 'No' : 0}, inplace = True)

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df1['gender'].replace({'Female':1,'Male':0},inplace=True)
# Out:
# C:\Users\ameym\AppData\Local\Temp\ipykernel_12400\698335744.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %% [markdown]
# ### One-Hot encoding for categorical columns

# %%
df2 = pd.get_dummies(data = df1, columns = ['Contract', 'PaymentMethod', 'InternetService'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'Contract_Month-to-month', 'Contract_One year', 'Contract_Two year',
#        'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No'],
#       dtype='object')

# %%
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 4975       0              0        1           0      72             1
# 1493       0              0        0           0      11             1
# 4429       1              0        1           1      70             1
# 5322       1              0        1           0      26             1
# 2828       0              0        0           0       1             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 4975              1               0             1                 1  ...
# 1493              0               1             0                 1  ...
# 4429              1               1             1                 1  ...
# 5322              0               0             1                 1  ...
# 2828              0               0             0                 0  ...
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# ...

# %% [markdown]
# ### Using MinMaxScaler to scale all numerical columns to values between [0,1]

# %%
columns_to_scale = ['tenure', 'MonthlyCharges', 'TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[columns_to_scale] = scaler.fit_transform(df2[columns_to_scale])

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# ...

# %% [markdown]
# ## Train-Test-Validation Split:

# %%
x = df2.drop(['Churn'], axis = 'columns')
y = df2['Churn']

from sklearn.model_selection import train_test_split
(x_train, x_test, y_train, y_test) = train_test_split(x, y, test_size = 0.2, random_state = 3)

# %%
x_train.shape
# Out:
# (5625, 26)

# %%
x_test.shape
# Out:
# (1407, 26)

# %%
x_val = x_train[0:500]
x_training = x_train[500: ]

y_val = y_train[0:500]
y_training = y_train[500: ]

# %% [markdown]
# ## Building the Model

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(512, activation='relu', input_shape=(26,)))
model.add(layers.Dense(20, activation = 'relu'))
model.add(layers.Dense(16, activation = 'relu'))
model.add(layers.Dense(1, activation = 'sigmoid'))

# %% [markdown]
# ### Compiling the model

# %%
model.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics = ['acc'])

# %% [markdown]
# ### Training the model

# %%
history = model.fit(x_training, y_training, epochs=70, validation_data = (x_val, y_val))
# Out:
# Epoch 1/70
# 161/161 [==============================] - 0s 2ms/step - loss: 0.1210 - acc: 0.9473 - val_loss: 0.6341 - val_acc: 0.8680
# Epoch 2/70
# 161/161 [==============================] - 0s 2ms/step - loss: 0.1219 - acc: 0.9440 - val_loss: 0.5634 - val_acc: 0.8560
# Epoch 3/70
# 161/161 [==============================] - 0s 2ms/step - loss: 0.1258 - acc: 0.9424 - val_loss: 0.5311 - val_acc: 0.8600
# Epoch 4/70
# 161/161 [==============================] - 0s 2ms/step - loss: 0.1215 - acc: 0.9469 - val_loss: 0.5240 - val_acc: 0.8500
# Epoch 5/70
# 161/161 [==============================] - 0s 1ms/step - loss: 0.1206 - acc: 0.9428 - val_loss: 0.4599 - val_acc: 0.8600
# Epoch 6/70
# 161/161 [==============================] - 0s 2ms/step - loss: 0.1228 - acc: 0.9458 - val_loss: 0.5351 - val_acc: 0.8460
# Epoch 7/70
# 161/161 [==============================] - 0s 1ms/step - loss: 0.1243 - acc: 0.9434 - val_loss: 0.5724 - val_acc: 0.8440
# Epoch 8/70
# ...

# %%
history_dict = history.history

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(history_dict['acc']) + 1)

# %%
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']
plt.plot(epochs, acc_values, 'bo', label='Training acc')
plt.plot(epochs, val_acc_values, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.predict(x_test)
# Out:
# 44/44 [==============================] - 0s 997us/step
# array([[6.1358631e-05],
#        [7.8002554e-01],
#        [9.9994105e-01],
#        ...,
#        [6.4847391e-06],
#        [5.7258924e-16],
#        [5.2207379e-06]], dtype=float32)

# %%
model.evaluate(x_test, y_test)
# Out:
# 44/44 [==============================] - 0s 1ms/step - loss: 1.9703 - acc: 0.7527
# [1.9703055620193481, 0.7526652216911316]
